# %%
child_Name=str(input("Name:"))
child_Age=int(input("Age:"))
child_Height=float(input("Height in inches:"))#in inches
child_Weight=float(input("Weight in pounds:")) #in pounds


child_BMI=(child_Weight/(child_Height**2))*703 #FORMULA FOR BMI OF CHILD
x=child_BMI
#Details about Health Conditions of Child
def data_BMI(x):
    if x<16:
        return "Severly Underweight"
    elif x<=16 and x<18.5:
        return "Underweight"
    elif x>=18.5 and x<25:
        return "Healthy"
    elif x>=25 and x<30:
        return "Overweight"
    else:
        return "Obese"

print(" ")
    
print("BMI of "+str(child_Name)+" is "+str(child_BMI)+" and he(she) is "+str(data_BMI(x)))

print(" ")


#Details about Calorie consumption


print("**************CALORIE CONSUMPTION*************")
print(" ")
milk=int(input("Milk in grams: "))
vegetables=int(input("Vegetables in grams: "))
meat=int(input("Meat in grams: "))
Lentils=int(input("Lentils in grams: "))
egg=int(input("Egg in grams: "))
Rice=int(input("Rice in grams: "))

milk_calorie=(100/100)*milk
vegetables_calorie=(85/100)*vegetables
meat_calorie=(143/100)*meat
Lentils_calorie=(113/100)*Lentils
Egg_calorie=(155/100)*egg
Rice_calorie=(130/100)*Rice

Total_calorie=milk_calorie+vegetables_calorie+meat_calorie+Lentils_calorie+Egg_calorie+Rice_calorie
y =Total_calorie

def calorie_required(y):
    
    a="The daily calorie consumption of "+str(child_Name)+ " is 800 and he (she) is taking "+str(Total_calorie)+" calorie ,he or she is nourished."
    b="The daily calorie consumption of "+str(child_Name)+ " is 800 and he (she) is taking "+str(Total_calorie)+" calorie ,he or she required more calories and he or she is under-nourished."
    
    
    if child_Age>0 and child_Age<2:
        if Total_calorie>=800:
            print(a)
        else:
            print(b)
    elif child_Age>=2 and child_Age<4:
        if Total_calorie>=1400:
            print(a)
        else:
            print(b)
    elif child_Age>=4 and child_Age<8:
        if Total_calorie>=1800:
            print(a)
        else:
            print(b)
    elif child_Age>=8 and child_Age<13:
        if Total_calorie>=2300:
            print(a)
        else:
            print(b)
    elif child_Age>=13 and child_Age<18:
        if Total_calorie>=3000:
            print(a)
        else:
            print(b)
    elif child_Age>=18 and child_Age<30:
        if Total_calorie>=3100:
            print(a)
        else :
            print(b)
    elif child_Age>=30 and child_Age<50:
        if Total_calorie>=2800 :
            print(a)
        else :
            print(b)
    elif child_Age>=50:
        if Total_calorie>=2600:
            print(a)
        else:
            print(b)
        
print(" ")
calorie_required(Total_calorie)
print(" ")
print("********************END*****************")
# Out:
# Name:AMAN
# Age:19
# Height in inches:67
# Weight in pounds:198
#
# BMI of AMAN is 31.007796836711965 and he(she) is Obese
#
# **************CALORIE CONSUMPTION*************
#
# Milk in grams: 123
# Vegetables in grams: 234
# Meat in grams: 334
# Lentils in grams: 344
# Egg in grams: 33
# Rice in grams: 44
#
# The daily calorie consumption of AMAN is 800 and he (she) is taking 1296.5900000000001 calorie ,he or she required more calories and he or she is under-nourished.
#
# ********************END*****************

# %% [markdown]
# ###
